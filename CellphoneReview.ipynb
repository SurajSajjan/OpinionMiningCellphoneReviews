# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
import nltk
import ast
import re
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import wordnet
nltk.download('sentiwordnet')
from nltk.corpus import sentiwordnet
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     C:\Users\suraj\AppData\Roaming\nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!

# %%
S10rev = pd.read_csv("D:/AMOD/Final Research Project/imp/S10_data.csv").dropna()
XRrev = pd.read_csv("D:/AMOD/Final Research Project/imp/XR_data.csv").dropna()

# %%
S10rev
# Out:
#       rating                                            content  subjectivity
# 0          2  The phone is great but when I got my package t...      0.750000
# 1          2                             Terrible customer care      1.000000
# 2          1    Calls drop, doesn’t pick up my data, constan...      0.666667
# 3          5                                      Awesome phone      1.000000
# 4          1   This one takes time to position, hard press, ...      0.541667
# ...      ...                                                ...           ...
# 1069       4   A brighter more vivid screen as my tab S3 wou...      0.716667
# 1070       5  Ok, so I think thst this is a great phone, and...      0.750000
# 1071       5    The camera on the s10e has some new cool fea...      0.534848
# 1072       5    I really enjoy the ultra-wide lens camera, t...      0.633333
# 1073       5    And of course, the new wallpapers are amazing:)      0.784848
#
# [1074 rows x 3 columns]

# %%
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer() 

def preprocess(sentence):
    sentence=str(sentence)
    sentence = sentence.lower()
    sentence=sentence.replace('{html}',"") 
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', sentence)
    rem_url=re.sub(r'http\S+', '',cleantext)
    rem_num = re.sub('[0-9]+', '', rem_url)
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(rem_num)  
    filtered_words = [w for w in tokens if len(w) > 2 if not w in stopwords.words('english')]
    stem_words=[stemmer.stem(w) for w in filtered_words]
    lemma_words=[lemmatizer.lemmatize(w) for w in stem_words]
    return " ".join(filtered_words)


S10rev['cleanContent']=S10rev['content'].map(lambda s:preprocess(s)) 
#S10rev.drop('content', axis=1, inplace=True)
XRrev['cleanContent']=XRrev['content'].map(lambda s:preprocess(s)) 
#XRrev.drop('content', axis=1, inplace=True)

# %%
S10rev
# Out:
#       rating                                            content  subjectivity  \
# 0          2  The phone is great but when I got my package t...      0.750000
# 1          2                             Terrible customer care      1.000000
# 2          1    Calls drop, doesn’t pick up my data, constan...      0.666667
# 3          5                                      Awesome phone      1.000000
# 4          1   This one takes time to position, hard press, ...      0.541667
# ...      ...                                                ...           ...
# 1069       4   A brighter more vivid screen as my tab S3 wou...      0.716667
# 1070       5  Ok, so I think thst this is a great phone, and...      0.750000
# 1071       5    The camera on the s10e has some new cool fea...      0.534848
# 1072       5    I really enjoy the ultra-wide lens camera, t...      0.633333
# 1073       5    And of course, the new wallpapers are amazing:)      0.784848
#
#                                            cleanContent
# 0              phone great got package protection phone
# 1                                terrible customer care
# 2     calls drop pick data constantly reboot phone h...
# 3                                         awesome phone
# 4     one takes time position hard press sec read fi...
# ...                                                 ...
# 1069       brighter vivid screen tab would also welcome
# 1070  think thst great phone everyone experience uni...
# 1071  camera new cool features image quality bit better
# 1072  really enjoy ultra wide lens camera something ...
# 1073                      course new wallpapers amazing
#
# [1074 rows x 4 columns]

# %%
search_values = ['design','camera','display','battery','fingerprint','finger print','processor','charging','fast charging','face recognition','recognition','face','storage','performance']

S10rev_useful = S10rev[S10rev.content.str.contains('|'.join(search_values ))]
XRrev_useful = XRrev[XRrev.content.str.contains('|'.join(search_values ))]

# %%
def pos_tag(sentences):
    wordsList = nltk.word_tokenize(sentences) 
    tagged = nltk.pos_tag(wordsList)   
    return tagged
    
S10rev_useful['tagged']=S10rev_useful['cleanContent'].map(lambda s:pos_tag(s))
XRrev_useful['tagged']=XRrev_useful['cleanContent'].map(lambda s:pos_tag(s))

# %%
pos_tag(XRrev_useful['cleanContent'].iloc[3])
# Out:
# [('great', 'JJ'), ('camera', 'NN')]

# %%
XRrev_useful = XRrev_useful[['content','cleanContent','tagged']]
S10rev_useful = S10rev_useful[['content','cleanContent','tagged']]

# %%
XRrev_useful = XRrev_useful.reset_index(drop=True)
S10rev_useful = S10rev_useful.reset_index(drop=True)

# %%
S10data_dict = S10rev_useful['tagged'].to_dict()
S10data_dict
# Out:
# {0: [('far', 'RB'),
#   ('experienced', 'JJ'),
#   ('glitches', 'NNS'),
#   ('continues', 'VBZ'),
#   ('run', 'VBP'),
#   ('apps', 'RB'),
#   ('quickly', 'RB'),
#   ('finger', 'RBR'),
#   ('print', 'JJ'),
#   ('scanner', 'NN'),
#   ('works', 'VBZ'),
#   ('great', 'JJ'),
#   ('gotten', 'JJ'),
#   ('hot', 'JJ'),
#   ('fast', 'NN'),
#   ('charging', 'VBG'),
#   ('included', 'VBD'),
#   ('fast', 'JJ'),
#   ('wall', 'NN'),
#   ('charger', 'NN'),
#   ('yootech', 'NN'),
#   ('wireless', 'NN'),
#   ('charger', 'NN'),
#   ('stand', 'VBP'),
#   ('issue', 'NN'),
#   ('turning', 'VBG'),
#   ('pocket', 'NN'),
#   ('like', 'IN'),
#   ('previous', 'JJ'),
#   ('phone', 'NN'),
#   ('used', 'VBN')],
#  1: [('fingerprint', 'NN'),
#   ('scanner', 'NN'),
#   ('works', 'VBZ'),
#   ('great', 'JJ')],
#  2: [('yeah', 'NN'),
#   ('sometimes', 'RB'),
#   ('try', 'VB'),
#   ('fingerprint', 'NN'),
#   ('twice', 'RB'),
#   ('honestly', 'RB'),
#   ('bother', 'JJR')],
#  3: [('camera', 'NN'), ('superb', 'NN')],
#  4: [('face', 'NN'),
#   ('recognition', 'NN'),
#   ('unlock', 'NN'),
#   ('works', 'VBZ'),
#   ('amazingly', 'RB'),
#   ('fast', 'JJ')],
#  5: [('includes', 'VBZ'),
#   ('time', 'NN'),
#   ('reads', 'NNS'),
#   ('finger', 'RB'),
#   ('print', 'VBP'),
#   ('wrong', 'JJ'),
#   ('disrupts', 'NNS'),
#   ('flow', 'JJ'),
#   ('hand', 'NN'),
#   ('motion', 'NN')],
#  6: [('fingerprint', 'NN'),
#   ('sensor', 'NN'),
#   ('right', 'JJ'),
#   ('side', 'NN'),
#   ('instead', 'RB'),
#   ('back', 'RB'),
#   ('bottom', 'JJ'),
#   ('screen', 'NN'),
#   ('weird', 'JJ'),
#   ('get', 'NN'),
#   ('used', 'VBN')],
#  7: [('cameras', 'NNS'),
#   ('take', 'VBP'),
#   ('amazing', 'JJ'),
#   ('pictures', 'NNS'),
#   ('three', 'CD'),
#   ('lenses', 'NNS'),
#   ('apertures', 'VBZ'),
#   ('give', 'JJ'),
#   ('lot', 'NN'),
#   ('flexibility', 'NN'),
#   ('photo', 'NN'),
#   ('taking', 'VBG')],
#  8: [('battery', 'NN'),
#   ('easily', 'RB'),
#   ('lasts', 'VBZ'),
#   ('day', 'NN'),
#   ('people', 'NNS'),
#   ('fine', 'VBP'),
#   ('unless', 'IN'),
#   ('heavy', 'JJ'),
#   ('power', 'NN'),
#   ('users', 'NNS')],
#  9: [('phones', 'NNS'), ('camera', 'NN'), ('amazing', 'NN')],
#  10: [('bad', 'JJ'),
#   ('camera', 'NN'),
#   ('downright', 'NN'),
#   ('mediocre', 'NN'),
#   ('compared', 'VBN'),
#   ('competition', 'NN')],
#  11: [('although', 'IN'),
#   ('enough', 'JJ'),
#   ('time', 'NN'),
#   ('rate', 'NN'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('seems', 'VBZ'),
#   ('pretty', 'RB'),
#   ('good', 'JJ')],
#  12: [('tried', 'JJ'), ('face', 'NN'), ('recognition', 'NN'), ('ugly', 'RB')],
#  13: [('great', 'JJ'),
#   ('phone', 'NN'),
#   ('camera', 'NN'),
#   ('audio', 'NN'),
#   ('beautiful', 'NN'),
#   ('design', 'NN')],
#  14: [('get', 'VB'),
#   ('fingerprint', 'NN'),
#   ('sensor', 'NN'),
#   ('one', 'CD'),
#   ('intuitive', 'JJ'),
#   ('places', 'NNS'),
#   ('works', 'VBZ'),
#   ('quite', 'RB'),
#   ('well', 'RB'),
#   ('fast', 'RB')],
#  15: [('time', 'NN'),
#   ('writing', 'VBG'),
#   ('samsung', 'NNS'),
#   ('released', 'VBN'),
#   ('dedicated', 'JJ'),
#   ('night', 'NN'),
#   ('mode', 'NN'),
#   ('camera', 'NN'),
#   ('app', 'NN'),
#   ('phone', 'NN'),
#   ('earlier', 'RBR'),
#   ('week', 'NN'),
#   ('though', 'IN'),
#   ('yet', 'RB'),
#   ('tested', 'VBN'),
#   ('say', 'VBP'),
#   ('isnt', 'NN'),
#   ('going', 'VBG'),
#   ('make', 'VBP'),
#   ('phone', 'NN'),
#   ('huawei', 'JJ'),
#   ('pro', 'JJ'),
#   ('take', 'VB'),
#   ('night', 'NN'),
#   ('time', 'NN'),
#   ('shots', 'NNS'),
#   ('absolute', 'VBP'),
#   ('darkness', 'JJ'),
#   ('improve', 'VB'),
#   ('photos', 'NNS'),
#   ('bit', 'RB'),
#   ('better', 'RBR'),
#   ('samsung', 'JJ'),
#   ('devices', 'NNS'),
#   ('similar', 'JJ'),
#   ('cameras', 'NNS'),
#   ('without', 'IN'),
#   ('software', 'NN'),
#   ('update', 'NN')],
#  16: [('picture', 'NN'),
#   ('quality', 'NN'),
#   ('great', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('outstanding', 'JJ')],
#  17: [('camera', 'NN'), ('function', 'NN'), ('powerful', 'JJ')],
#  18: [('love', 'NN'),
#   ('samsung', 'NN'),
#   ('camera', 'NN'),
#   ('excellent', 'JJ'),
#   ('phone', 'NN'),
#   ('works', 'NNS'),
#   ('advertised', 'VBD')],
#  19: [('like', 'IN'),
#   ('integrates', 'NNS'),
#   ('car', 'NN'),
#   ('pretty', 'RB'),
#   ('well', 'RB'),
#   ('maps', 'JJ'),
#   ('cool', 'JJ'),
#   ('feature', 'NN'),
#   ('allow', 'VBP'),
#   ('display', 'NN'),
#   ('map', 'NN'),
#   ('satelite', 'JJ'),
#   ('view', 'NN')],
#  20: [('runs', 'NNS'),
#   ('smooth', 'VBP'),
#   ('butter', 'NN'),
#   ('screen', 'NN'),
#   ('cameras', 'NNS'),
#   ('breathtaking', 'VBG')],
#  21: [('fingerprint', 'NN'),
#   ('works', 'VBZ'),
#   ('extremly', 'RB'),
#   ('awful', 'JJ')],
#  22: [('fingerprint', 'NN'),
#   ('scanner', 'NN'),
#   ('extraordinarily', 'RB'),
#   ('fast', 'RB'),
#   ('screen', 'JJ'),
#   ('beautiful', 'JJ'),
#   ('camera', 'NN'),
#   ('clear', 'JJ'),
#   ('use', 'NN'),
#   ('ultra', 'JJ'),
#   ('wide', 'JJ'),
#   ('angle', 'NN'),
#   ('time', 'NN')],
#  23: [('added', 'JJ'),
#   ('pictures', 'NNS'),
#   ('took', 'VBD'),
#   ('great', 'JJ'),
#   ('camera', 'NN')],
#  24: [('even', 'RB'),
#   ('case', 'NN'),
#   ('installed', 'VBD'),
#   ('subtle', 'JJ'),
#   ('warm', 'JJ'),
#   ('silver', 'NN'),
#   ('bezel', 'NN'),
#   ('visible', 'JJ'),
#   ('bottom', 'JJ'),
#   ('power', 'NN'),
#   ('button', 'NN'),
#   ('camera', 'NN'),
#   ('bezel', 'NN'),
#   ('warm', 'JJ'),
#   ('metal', 'NN'),
#   ('black', 'JJ'),
#   ('case', 'NN'),
#   ('super', 'JJ'),
#   ('cool', 'NN')],
#  25: [('still', 'RB'),
#   ('playing', 'VBG'),
#   ('camera', 'NN'),
#   ('functions', 'NNS'),
#   ('still', 'RB'),
#   ('good', 'JJ')],
#  26: [('awesome', 'JJ'),
#   ('camera', 'NN'),
#   ('dont', 'NN'),
#   ('ever', 'RB'),
#   ('miss', 'VBZ'),
#   ('cameras', 'NNS')],
#  27: [('complain', 'NN'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('get', 'VB'),
#   ('charging', 'VBG'),
#   ('case', 'NN')],
#  28: [('needed', 'VBN'),
#   ('phone', 'NN'),
#   ('replacement', 'NN'),
#   ('right', 'RB'),
#   ('away', 'RB'),
#   ('picked', 'VBN'),
#   ('unlocked', 'JJ'),
#   ('galaxy', 'NN'),
#   ('even', 'RB'),
#   ('though', 'IN'),
#   ('need', 'NN'),
#   ('storage', 'NN')],
#  29: [('still', 'RB'),
#   ('sure', 'JJ'),
#   ('heck', 'NN'),
#   ('use', 'NN'),
#   ('storage', 'NN')],
#  30: [('battery', 'NN'),
#   ('life', 'NN'),
#   ('amazing', 'VBG'),
#   ('processor', 'NN'),
#   ('fast', 'NN')],
#  31: [('phone', 'NN'),
#   ('beautiful', 'NN'),
#   ('works', 'VBZ'),
#   ('well', 'RB'),
#   ('battery', 'JJ'),
#   ('life', 'NN'),
#   ('could', 'MD'),
#   ('better', 'VB')],
#  32: [('phone', 'NN'),
#   ('amazing', 'VBG'),
#   ('think', 'VBP'),
#   ('fantastic', 'JJ'),
#   ('cameras', 'NNS'),
#   ('spectacular', 'JJ'),
#   ('clear', 'JJ'),
#   ('gadget', 'NN'),
#   ('expert', 'NN'),
#   ('phone', 'NN'),
#   ('perfect', 'JJ'),
#   ('come', 'VBN'),
#   ('thin', 'JJ'),
#   ('glass', 'NN'),
#   ('screen', 'NN'),
#   ('protector', 'NN'),
#   ('already', 'RB'),
#   ('placed', 'VBD'),
#   ('phone', 'NN')],
#  33: [('nice', 'JJ'),
#   ('phone', 'NN'),
#   ('model', 'NN'),
#   ('phone', 'NN'),
#   ('let', 'VBD'),
#   ('turn', 'VB'),
#   ('camera', 'NN'),
#   ('shutter', 'NN'),
#   ('sound', 'NN'),
#   ('matter', 'NN'),
#   ('tried', 'VBD'),
#   ('settings', 'NNS')],
#  34: [('gorgeous', 'JJ'), ('phone', 'NN'), ('display', 'NN'), ('best', 'JJS')],
#  35: [('also', 'RB'),
#   ('would', 'MD'),
#   ('careful', 'VB'),
#   ('buying', 'VBG'),
#   ('screen', 'JJ'),
#   ('protectors', 'NNS'),
#   ('cover', 'VBP'),
#   ('sensor', 'NN'),
#   ('thick', 'JJ'),
#   ('recognize', 'NN'),
#   ('fingerprint', 'NN')],
#  36: [('issue', 'NN'),
#   ('previous', 'JJ'),
#   ('charging', 'VBG'),
#   ('cables', 'NNS'),
#   ('null', 'RB'),
#   ('different', 'JJ'),
#   ('charging', 'VBG'),
#   ('port', 'NN'),
#   ('requiring', 'VBG'),
#   ('purchase', 'NN'),
#   ('new', 'JJ'),
#   ('charging', 'VBG'),
#   ('cables', 'NNS')],
#  37: [('heard', 'NN'),
#   ('read', 'VBD'),
#   ('fingerprint', 'NN'),
#   ('samsung', 'RB'),
#   ('hard', 'RB'),
#   ('use', 'NN')],
#  38: [('call', 'NN'),
#   ('quality', 'NN'),
#   ('greatest', 'JJS'),
#   ('signal', 'JJ'),
#   ('strength', 'NN'),
#   ('terrible', 'JJ'),
#   ('compared', 'VBN'),
#   ('fingerprint', 'NN'),
#   ('scanner', 'NN'),
#   ('way', 'NN'),
#   ('high', 'JJ'),
#   ('smart', 'JJ'),
#   ('lock', 'NN'),
#   ('feature', 'NN'),
#   ('barely', 'RB'),
#   ('works', 'VBZ'),
#   ('even', 'RB'),
#   ('gps', 'JJ'),
#   ('calibration', 'NN'),
#   ('ugh', 'IN'),
#   ('reviewing', 'VBG'),
#   ('used', 'VBN'),
#   ('clear', 'JJ')],
#  39: [('unfortunately', 'RB'),
#   ('fell', 'VBD'),
#   ('victim', 'JJ'),
#   ('battery', 'NN'),
#   ('drain', 'NN'),
#   ('issues', 'NNS')],
#  40: [('great', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('excellent', 'JJ'),
#   ('processing', 'VBG'),
#   ('speed', 'NN'),
#   ('shape', 'NN'),
#   ('image', 'NN')],
#  41: [('super', 'JJ'), ('fast', 'NN'), ('processor', 'NN')],
#  42: [('camera', 'NN'),
#   ('seems', 'VBZ'),
#   ('pretty', 'RB'),
#   ('high', 'JJ'),
#   ('end', 'NN')],
#  43: [('plus', 'CC'), ('longer', 'RBR'), ('battery', 'JJ'), ('life', 'NN')],
#  44: [('happy', 'JJ'),
#   ('phone', 'NN'),
#   ('sturdiness', 'NN'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('functionality', 'NN'),
#   ('etc', 'NN')],
#  45: [('one', 'CD'),
#   ('thing', 'NN'),
#   ('say', 'VBP'),
#   ('certain', 'JJ'),
#   ('fingerprint', 'NN'),
#   ('scanner', 'NN'),
#   ('greatly', 'RB'),
#   ('improved', 'VBD')],
#  46: [('back', 'RB'),
#   ('fingerprint', 'NN'),
#   ('sensor', 'NN'),
#   ('power', 'NN'),
#   ('button', 'NN'),
#   ('always', 'RB'),
#   ('super', 'VBD'),
#   ('fast', 'JJ'),
#   ('times', 'NNS'),
#   ('feel', 'VBP'),
#   ('awkward', 'RB'),
#   ('use', 'NN')],
#  47: [('lied', 'VBN'),
#   ('believe', 'VBP'),
#   ('anyone', 'NN'),
#   ('tells', 'NNS'),
#   ('battery', 'RB'),
#   ('great', 'JJ')],
#  48: [('clean', 'JJ'),
#   ('runs', 'NNS'),
#   ('much', 'RB'),
#   ('faster', 'RBR'),
#   ('new', 'JJ'),
#   ('processor', 'NN')],
#  49: [('really', 'RB'),
#   ('satisfied', 'JJ'),
#   ('product', 'NN'),
#   ('need', 'NN'),
#   ('compromise', 'NN'),
#   ('battery', 'NN')],
#  50: [('gone', 'VBN'),
#   ('percent', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('day', 'NN'),
#   ('good', 'JJ')],
#  51: [('read', 'VB'),
#   ('many', 'JJ'),
#   ('reviews', 'NNS'),
#   ('wrong', 'JJ'),
#   ('model', 'NN'),
#   ('snapdragon', 'NN'),
#   ('processor', 'NN')],
#  52: [('terrible', 'JJ'),
#   ('horrible', 'JJ'),
#   ('crappy', 'JJ'),
#   ('blury', 'NN'),
#   ('camera', 'NN'),
#   ('samsung', 'NN'),
#   ('screw', 'VBD'),
#   ('one', 'CD'),
#   ('bad', 'JJ'),
#   ('camera', 'NN')],
#  53: [('loads', 'NNS'),
#   ('storage', 'NN'),
#   ('unbelievable', 'JJ'),
#   ('photos', 'NNS'),
#   ('battery', 'RB'),
#   ('never', 'RB'),
#   ('quits', 'NNS')],
#  54: [('started', 'VBN'),
#   ('getting', 'VBG'),
#   ('really', 'RB'),
#   ('hot', 'JJ'),
#   ('losing', 'VBG'),
#   ('battery', 'NN'),
#   ('really', 'RB'),
#   ('fast', 'RB')],
#  55: [('speechless', 'NN'),
#   ('oneui', 'NN'),
#   ('wow', 'NN'),
#   ('samsung', 'NN'),
#   ('finally', 'RB'),
#   ('got', 'VBD'),
#   ('right', 'JJ'),
#   ('user', 'NN'),
#   ('friendly', 'RB'),
#   ('fluid', 'JJ'),
#   ('feels', 'NNS'),
#   ('comfortable', 'JJ'),
#   ('hold', 'VBP'),
#   ('much', 'JJ'),
#   ('better', 'JJR'),
#   ('iphone', 'NN'),
#   ('screen', 'NN'),
#   ('gorgeous', 'JJ'),
#   ('little', 'JJ'),
#   ('bright', 'JJ'),
#   ('night', 'NN'),
#   ('bixby', 'NN'),
#   ('routine', 'NN'),
#   ('eliminated', 'VBD'),
#   ('need', 'JJ'),
#   ('tasker', 'NN'),
#   ('headphone', 'NN'),
#   ('jack', 'NN'),
#   ('although', 'IN'),
#   ('use', 'NN'),
#   ('nice', 'NNS'),
#   ('know', 'VBP'),
#   ('samsung', 'JJ'),
#   ('health', 'NN'),
#   ('useful', 'JJ'),
#   ('hail', 'NN'),
#   ('ram', 'NN'),
#   ('apps', 'NN'),
#   ('opened', 'VBD'),
#   ('within', 'IN'),
#   ('hour', 'NN'),
#   ('still', 'RB'),
#   ('battery', 'JJ'),
#   ('life', 'NN'),
#   ('good', 'JJ'),
#   ('excellent', 'JJ'),
#   ('pretty', 'RB'),
#   ('par', 'JJ'),
#   ('iphone', 'NN'),
#   ('max', 'NN'),
#   ('meh', 'NN'),
#   ('power', 'NN'),
#   ('button', 'NN'),
#   ('bit', 'NN'),
#   ('high', 'JJ'),
#   ('need', 'NN'),
#   ('adjust', 'VBP'),
#   ('grip', 'NN'),
#   ('turning', 'VBG'),
#   ('screen', 'NN'),
#   ('back', 'RB'),
#   ('camera', 'NN'),
#   ('good', 'JJ'),
#   ('pretty', 'RB'),
#   ('much', 'JJ'),
#   ('feels', 'NNS'),
#   ('iphone', 'VBP'),
#   ('disclaimer', 'JJ'),
#   ('dummy', 'NN'),
#   ('photo', 'NN'),
#   ('taker', 'NN'),
#   ('pretty', 'RB'),
#   ('much', 'JJ'),
#   ('point', 'NN'),
#   ('shoot', 'NN'),
#   ('samsung', 'NN'),
#   ('still', 'RB'),
#   ('nags', 'RB'),
#   ('much', 'JJ')],
#  56: [('want', 'NN'),
#   ('see', 'NN'),
#   ('face', 'NN'),
#   ('without', 'IN'),
#   ('looking', 'VBG'),
#   ('like', 'IN'),
#   ('year', 'NN'),
#   ('old', 'JJ'),
#   ('damn', 'NN'),
#   ('curved', 'VBD'),
#   ('screen', 'JJ'),
#   ('felt', 'NNS'),
#   ('like', 'IN'),
#   ('even', 'RB'),
#   ('worse', 'JJR'),
#   ('maybe', 'RB'),
#   ('size', 'NN'),
#   ('case', 'NN'),
#   ('helped', 'VBD'),
#   ('accidental', 'JJ'),
#   ('touches', 'NNS'),
#   ('god', 'VBP'),
#   ('still', 'RB'),
#   ('happening', 'VBG'),
#   ('oneui', 'PRP'),
#   ('awesome', 'JJ'),
#   ('way', 'NN'),
#   ('treat', 'NN'),
#   ('folders', 'NNS')],
#  57: [('battery', 'NN'), ('life', 'NN'), ('great', 'JJ')],
#  58: [('nice', 'JJ'),
#   ('camcorder', 'NN'),
#   ('cheap', 'NN'),
#   ('cell', 'NN'),
#   ('phone', 'NN'),
#   ('sluggish', 'JJ'),
#   ('bucks', 'NNS'),
#   ('digital', 'JJ'),
#   ('camera', 'NN'),
#   ('ish', 'JJ'),
#   ('maybe', 'RB'),
#   ('scientific', 'JJ'),
#   ('calculator', 'NN'),
#   ('usually', 'RB'),
#   ('ish', 'JJ'),
#   ('good', 'JJ'),
#   ('one', 'CD'),
#   ('physics', 'NN'),
#   ('calculations', 'NNS'),
#   ('bored', 'VBD'),
#   ('want', 'JJ'),
#   ('solve', 'NN'),
#   ('string', 'VBG'),
#   ('theory', 'NN'),
#   ('problems', 'NNS')],
#  59: [('hardware', 'NN'),
#   ('decent', 'JJ'),
#   ('great', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('almost', 'RB'),
#   ('great', 'JJ'),
#   ('camera', 'NN')],
#  60: [('get', 'VB'),
#   ('oneplus', 'JJ'),
#   ('pro', 'FW'),
#   ('everything', 'NN'),
#   ('better', 'RBR'),
#   ('screen', 'NN'),
#   ('constant', 'JJ'),
#   ('updates', 'VBZ'),
#   ('maybe', 'RB'),
#   ('camera', 'NN'),
#   ('slightly', 'RB'),
#   ('worse', 'RBR'),
#   ('debatable', 'JJ')],
#  61: [('finger', 'NN'),
#   ('print', 'NN'),
#   ('reader', 'NN'),
#   ('easy', 'JJ'),
#   ('use', 'NN'),
#   ('battery', 'NN'),
#   ('lasts', 'NNS'),
#   ('day', 'NN')],
#  62: [('finger', 'NN'),
#   ('print', 'NN'),
#   ('scanner', 'NN'),
#   ('little', 'JJ'),
#   ('finicky', 'JJ'),
#   ('think', 'NNS'),
#   ('take', 'VBP'),
#   ('getting', 'VBG'),
#   ('used', 'VBN'),
#   ('face', 'NN'),
#   ('scanner', 'NN'),
#   ('annoying', 'VBG'),
#   ('since', 'IN'),
#   ('wearing', 'VBG'),
#   ('glasses', 'NNS'),
#   ('contacts', 'NNS'),
#   ('pleasantly', 'RB'),
#   ('surprised', 'VBD'),
#   ('still', 'RB'),
#   ('works', 'NNS')],
#  63: [('camera', 'NN'),
#   ('resolution', 'NN'),
#   ('absolutely', 'RB'),
#   ('fantastic', 'JJ')],
#  64: [('different', 'JJ'), ('processors', 'NNS'), ('cheaper', 'VBP')],
#  65: [('seen', 'VBN'),
#   ('dramatic', 'JJ'),
#   ('increase', 'NN'),
#   ('battery', 'NN'),
#   ('life', 'NN')],
#  66: [('like', 'IN'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('great', 'JJ'),
#   ('cameras', 'NNS')],
#  67: [('issue', 'NN'),
#   ('aware', 'JJ'),
#   ('bought', 'VBD'),
#   ('low', 'JJ'),
#   ('light', 'NN'),
#   ('camera', 'NN')],
#  68: [('awesome', 'JJ'),
#   ('screen', 'NN'),
#   ('beautiful', 'JJ'),
#   ('phone', 'NN'),
#   ('color', 'NN'),
#   ('amazing', 'VBG'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('great', 'JJ'),
#   ('watch', 'NN'),
#   ('videos', 'NN'),
#   ('taking', 'VBG'),
#   ('pictures', 'NNS')],
#  69: [('lovely', 'RB'),
#   ('ladies', 'VBZ'),
#   ('phone', 'NN'),
#   ('color', 'NN'),
#   ('shape', 'NN'),
#   ('big', 'JJ'),
#   ('slender', 'NN'),
#   ('great', 'JJ'),
#   ('display', 'NN')],
#  70: [('love', 'VB'),
#   ('newer', 'JJR'),
#   ('features', 'NNS'),
#   ('storage', 'NN'),
#   ('longer', 'RB'),
#   ('battery', 'JJ'),
#   ('life', 'NN')],
#  71: [('phones', 'NNS'),
#   ('support', 'NN'),
#   ('mirrorlink', 'VBP'),
#   ('use', 'NN'),
#   ('car', 'NN'),
#   ('built', 'VBN'),
#   ('display', 'NN'),
#   ('navigate', 'NN'),
#   ('using', 'VBG'),
#   ('paid', 'VBN'),
#   ('app', 'NN'),
#   ('sygic', 'NN'),
#   ('car', 'NN'),
#   ('connected', 'VBN'),
#   ('navigation', 'NN'),
#   ('microsoft', 'JJ'),
#   ('member', 'NN'),
#   ('consortium', 'NN'),
#   ('behind', 'IN'),
#   ('mirrorlink', 'NN'),
#   ('never', 'RB'),
#   ('finished', 'VBD'),
#   ('implementing', 'VBG'),
#   ('support', 'NN'),
#   ('windows', 'NNS'),
#   ('phone', 'NN'),
#   ('mobile', 'NN')],
#  72: [('never', 'RB'),
#   ('experienced', 'VBN'),
#   ('bright', 'JJ'),
#   ('adaptive', 'JJ'),
#   ('resolution', 'NN'),
#   ('display', 'NN')],
#  73: [('fingerprint', 'NN'),
#   ('scanner', 'NN'),
#   ('fancy', 'NN'),
#   ('supposed', 'VBD'),
#   ('secure', 'NN'),
#   ('failed', 'VBD'),
#   ('miserably', 'RB'),
#   ('saved', 'JJ'),
#   ('fingerprints', 'NNS'),
#   ('first', 'RB'),
#   ('two', 'CD'),
#   ('times', 'NNS')],
#  74: [('recognition', 'NN')],
#  75: [('like', 'IN'),
#   ('reduced', 'VBN'),
#   ('bezel', 'NN'),
#   ('display', 'NN'),
#   ('essentially', 'RB'),
#   ('requires', 'VBZ'),
#   ('kind', 'NN'),
#   ('case', 'NN'),
#   ('increase', 'NN'),
#   ('distance', 'NN'),
#   ('hand', 'NN'),
#   ('phone', 'NN'),
#   ('accidental', 'JJ'),
#   ('touches', 'NNS'),
#   ('common', 'JJ'),
#   ('without', 'IN'),
#   ('case', 'NN')],
#  76: [('fingerprint', 'NN'),
#   ('sensor', 'NN'),
#   ('high', 'JJ'),
#   ('difficult', 'JJ'),
#   ('reach', 'NN'),
#   ('volume', 'NN'),
#   ('buttons', 'NNS'),
#   ('directly', 'RB'),
#   ('across', 'IN'),
#   ('side', 'NN'),
#   ('causing', 'NN'),
#   ('unwanted', 'JJ'),
#   ('screen', 'NN'),
#   ('shots', 'NNS'),
#   ('frequently', 'RB')],
#  77: [('camera', 'NN'),
#   ('option', 'NN'),
#   ('fake', 'VBP'),
#   ('long', 'JJ'),
#   ('exposure', 'NN'),
#   ('like', 'IN'),
#   ('iphone', 'NN')],
#  78: [('wide', 'JJ'),
#   ('angle', 'NN'),
#   ('camera', 'NN'),
#   ('able', 'JJ'),
#   ('used', 'JJ'),
#   ('pro', 'FW'),
#   ('mode', 'NN')],
#  79: [('fingerprint', 'NN'),
#   ('recognition', 'NN'),
#   ('seems', 'VBZ'),
#   ('pretty', 'JJ'),
#   ('worthless', 'NN')],
#  80: [('wanted', 'VBN'),
#   ('get', 'NN'),
#   ('iphone', 'NN'),
#   ('trying', 'VBG'),
#   ('noticed', 'VBN'),
#   ('better', 'RBR'),
#   ('camera', 'NN'),
#   ('beautiful', 'JJ'),
#   ('filters', 'NNS')],
#  81: [('fast', 'RB'),
#   ('good', 'JJ'),
#   ('processor', 'NN'),
#   ('lots', 'NNS'),
#   ('ram', 'VBP'),
#   ('fingerprint', 'JJ'),
#   ('reader', 'NN'),
#   ('clunky', 'NN'),
#   ('bixby', 'IN'),
#   ('button', 'NN'),
#   ('total', 'JJ'),
#   ('deal', 'NN'),
#   ('breaker', 'NN')],
#  82: [('spectacular', 'JJ'), ('interface', 'NN'), ('great', 'JJ')],
#  83: [('cameras', 'NNS'),
#   ('take', 'VBP'),
#   ('amazing', 'JJ'),
#   ('shots', 'NNS'),
#   ('lot', 'VBP'),
#   ('fun', 'NN'),
#   ('options', 'NNS'),
#   ('use', 'VBP'),
#   ('taking', 'VBG'),
#   ('photos', 'NNS')],
#  84: [('faster', 'RBR'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('amazing', 'VBG'),
#   ('screen', 'NN'),
#   ('beautifully', 'RB'),
#   ('crisp', 'VB')],
#  85: [('fingerprint', 'NN'),
#   ('unlock', 'NN'),
#   ('perfect', 'JJ'),
#   ('vast', 'JJ'),
#   ('improvement', 'NN')],
#  86: [('fast', 'RB'),
#   ('smooth', 'JJ'),
#   ('great', 'JJ'),
#   ('display', 'NN'),
#   ('battery', 'NN'),
#   ('life', 'NN')],
#  87: [('packed', 'JJ'),
#   ('features', 'NNS'),
#   ('great', 'JJ'),
#   ('battery', 'JJ'),
#   ('life', 'NN'),
#   ('amazing', 'VBG'),
#   ('photos', 'NNS')],
#  88: [('samsung', 'NN'),
#   ('always', 'RB'),
#   ('makes', 'VBZ'),
#   ('stupid', 'JJ'),
#   ('inventions', 'NNS'),
#   ('screen', 'JJ'),
#   ('finger', 'NN'),
#   ('print', 'NN'),
#   ('reader', 'NN'),
#   ('curved', 'VBD'),
#   ('screen', 'JJ'),
#   ('etc', 'NN')],
#  89: [('went', 'VBD'),
#   ('super', 'JJ'),
#   ('hot', 'JJ'),
#   ('wasnt', 'NN'),
#   ('even', 'RB'),
#   ('charging', 'VBG'),
#   ('cool', 'JJ'),
#   ('area', 'NN'),
#   ('well', 'RB')],
#  90: [('good', 'JJ'),
#   ('thing', 'NN'),
#   ('long', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('worth', 'NN')],
#  91: [('great', 'JJ'),
#   ('screen', 'NN'),
#   ('good', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('everything', 'NN'),
#   ('works', 'NNS')],
#  92: [('love', 'VB'),
#   ('forward', 'RB'),
#   ('facing', 'VBG'),
#   ('cameras', 'NNS')],
#  93: [('outstanding', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('compared', 'VBN'),
#   ('phone', 'NN'),
#   ('ever', 'RB'),
#   ('owned', 'VBD'),
#   ('including', 'VBG'),
#   ('note', 'NN')],
#  94: [('screen', 'NN'),
#   ('awesomely', 'RB'),
#   ('brigh', 'JJ'),
#   ('face', 'NN'),
#   ('recognition', 'NN'),
#   ('fingerprint', 'NN'),
#   ('sensor', 'NN'),
#   ('works', 'VBZ'),
#   ('great', 'JJ'),
#   ('time', 'NN'),
#   ('got', 'VBD'),
#   ('right', 'JJ')],
#  95: [('camera', 'NN'),
#   ('specs', 'NN'),
#   ('looked', 'VBD'),
#   ('amazing', 'JJ'),
#   ('low', 'JJ'),
#   ('light', 'NN'),
#   ('performance', 'NN'),
#   ('underwhelming', 'NN')],
#  96: [('finger', 'NN'),
#   ('print', 'NN'),
#   ('reader', 'NN'),
#   ('work', 'NN'),
#   ('everytime', 'RB'),
#   ('gets', 'VBZ'),
#   ('annoying', 'VBG')],
#  97: [('battery', 'NN'),
#   ('life', 'NN'),
#   ('easily', 'RB'),
#   ('lasts', 'VBZ'),
#   ('day', 'NN'),
#   ('plenty', 'NN'),
#   ('spare', 'NN')],
#  98: [('fingerprint', 'NN'),
#   ('reader', 'NN'),
#   ('pretty', 'RB'),
#   ('accurate', 'JJ'),
#   ('becomes', 'NNS'),
#   ('better', 'RBR'),
#   ('use', 'NN')],
#  99: [('extremely', 'RB'),
#   ('fast', 'RB'),
#   ('fabulous', 'JJ'),
#   ('camera', 'NN'),
#   ('many', 'JJ'),
#   ('great', 'JJ'),
#   ('features', 'NNS'),
#   ('highly', 'RB'),
#   ('recommend', 'VBP')],
#  100: [('love', 'VB'),
#   ('new', 'JJ'),
#   ('samsung', 'NN'),
#   ('galaxy', 'NN'),
#   ('screen', 'NN'),
#   ('size', 'NN'),
#   ('phenomenal', 'JJ'),
#   ('camera', 'NN'),
#   ('outstanding', 'JJ'),
#   ('thanks', 'NNS'),
#   ('samsung', 'VBD')],
#  101: [('really', 'RB'),
#   ('really', 'RB'),
#   ('anxious', 'JJ'),
#   ('try', 'NN'),
#   ('camera', 'NN')],
#  102: [('camera', 'NN'), ('amazing', 'NN')],
#  103: [('meters', 'NNS'),
#   ('minutes', 'NNS'),
#   ('amazing', 'VBG'),
#   ('camera', 'NN'),
#   ('super', 'NN'),
#   ('bright', 'VBD'),
#   ('super', 'JJ'),
#   ('dark', 'NN'),
#   ('places', 'NNS'),
#   ('face', 'VBP'),
#   ('recognition', 'NN'),
#   ('fingerprint', 'NN'),
#   ('sensor', 'NN'),
#   ('works', 'VBZ'),
#   ('time', 'NN')],
#  104: [('sure', 'JJ'),
#   ('screen', 'JJ'),
#   ('fingerprint', 'NN'),
#   ('sensor', 'NN'),
#   ('would', 'MD'),
#   ('work', 'VB'),
#   ('good', 'JJ'),
#   ('since', 'IN'),
#   ('first', 'JJ'),
#   ('kind', 'NN')],
#  105: [('many', 'JJ'),
#   ('great', 'JJ'),
#   ('features', 'NNS'),
#   ('camera', 'VBP'),
#   ('amazing', 'VBG'),
#   ('happy', 'JJ'),
#   ('purchase', 'NN')],
#  106: [('can', 'MD'),
#   ('not', 'RB'),
#   ('use', 'VB'),
#   ('fingerprint', 'NN'),
#   ('reader', 'NN'),
#   ('even', 'RB'),
#   ('adjustment', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('far', 'RB'),
#   ('worse', 'JJR'),
#   ('galaxy', 'NN'),
#   ('edge', 'NN'),
#   ('using', 'VBG'),
#   ('fsr', 'NN'),
#   ('less', 'JJR')],
#  107: [('great', 'JJ'),
#   ('phone', 'NN'),
#   ('great', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('really', 'RB'),
#   ('glad', 'JJ'),
#   ('bought', 'VBD'),
#   ('unlocked', 'JJ'),
#   ('version', 'NN')],
#  108: [('time', 'NN'),
#   ('tell', 'VB'),
#   ('battery', 'JJ'),
#   ('life', 'NN'),
#   ('already', 'RB'),
#   ('charging', 'VBG'),
#   ('connection', 'NN'),
#   ('feels', 'NNS'),
#   ('snug', 'VBP'),
#   ('problems', 'NNS'),
#   ('end', 'VBP'),
#   ('getting', 'VBG'),
#   ('good', 'JJ'),
#   ('charging', 'NN'),
#   ('connection', 'NN')],
#  109: [('battery', 'NN'),
#   ('far', 'RB'),
#   ('lasts', 'VBZ'),
#   ('easy', 'JJ'),
#   ('hours', 'NNS'),
#   ('wifi', 'VBP'),
#   ('streaming', 'VBG'),
#   ('videos', 'NNS'),
#   ('tunein', 'RB'),
#   ('radio', 'NN')],
#  110: [('wide', 'JJ'),
#   ('angle', 'NN'),
#   ('lens', 'VBZ'),
#   ('camera', 'NN'),
#   ('excellent', 'NN')],
#  111: [('side', 'NN'),
#   ('fingerprint', 'NN'),
#   ('scanner', 'NN'),
#   ('little', 'JJ'),
#   ('high', 'JJ'),
#   ('placement', 'NN'),
#   ('getting', 'VBG'),
#   ('used', 'VBN')],
#  112: [('guess', 'NN'),
#   ('design', 'NN'),
#   ('flaw', 'NN'),
#   ('sense', 'NN'),
#   ('phone', 'NN'),
#   ('cases', 'NNS'),
#   ('hard', 'RB'),
#   ('make', 'VBP'),
#   ('well', 'RB'),
#   ('phone', 'NN')],
#  113: [('great', 'JJ'), ('camera', 'NN')],
#  114: [('processor', 'NN'), ('remarkably', 'RB'), ('fast', 'RB')],
#  115: [('fingerprint', 'NN'),
#   ('reader', 'NN'),
#   ('fast', 'VBD'),
#   ('reliable', 'JJ')],
#  116: [('expected', 'VBN'),
#   ('phone', 'NN'),
#   ('faster', 'RBR'),
#   ('battery', 'NN'),
#   ('lasts', 'VBZ'),
#   ('longer', 'RB'),
#   ('aging', 'VBG'),
#   ('although', 'IN'),
#   ('overly', 'RB'),
#   ('impressive', 'JJ'),
#   ('new', 'JJ'),
#   ('phone', 'NN')],
#  117: [('update', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('phone', 'NN'),
#   ('disappointing', 'VBG'),
#   ('new', 'JJ'),
#   ('phone', 'NN')],
#  118: [('fast', 'RB'),
#   ('fingerprint', 'JJ'),
#   ('reader', 'NN'),
#   ('way', 'NN'),
#   ('better', 'RBR'),
#   ('emoji', 'JJ'),
#   ('feature', 'NN'),
#   ('funny', 'NN')],
#  119: [('love', 'VB'), ('amazing', 'NN'), ('camera', 'NN')],
#  120: [('curve', 'NN'), ('design', 'NN'), ('favorite', 'NN')],
#  121: [('hold', 'VB'),
#   ('fake', 'JJ'),
#   ('one', 'CD'),
#   ('reviewer', 'NN'),
#   ('said', 'VBD'),
#   ('fingerprint', 'NN'),
#   ('scanner', 'NN'),
#   ('screen', 'NN')],
#  122: [('phone', 'NN'),
#   ('works', 'NNS'),
#   ('perfect', 'VBP'),
#   ('good', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('brand', 'NN'),
#   ('new', 'JJ'),
#   ('box', 'NN'),
#   ('fast', 'RB'),
#   ('screen', 'JJ'),
#   ('nice', 'JJ')],
#  123: [('great', 'JJ'),
#   ('phone', 'NN'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('great', 'JJ'),
#   ('charges', 'NNS'),
#   ('fast', 'RB'),
#   ('face', 'VBP'),
#   ('unlock', 'JJ'),
#   ('secure', 'NN'),
#   ('problems', 'NNS'),
#   ('display', 'VBP'),
#   ('fingerprint', 'NN'),
#   ('sensor', 'NN')],
#  124: [('sometimes', 'RB'),
#   ('fingerprint', 'JJ'),
#   ('reader', 'NN'),
#   ('would', 'MD'),
#   ('bit', 'VB'),
#   ('slower', 'JJR'),
#   ('oneplus', 'JJ'),
#   ('pro', 'FW'),
#   ('bad', 'JJ')],
#  125: [('face', 'NN'),
#   ('recognition', 'NN'),
#   ('works', 'VBZ'),
#   ('great', 'JJ')],
#  126: [('thankfully', 'RB'),
#   ('face', 'NN'),
#   ('unlock', 'JJ'),
#   ('pretty', 'RB'),
#   ('smooth', 'JJ'),
#   ('comfortable', 'JJ'),
#   ('less', 'JJR'),
#   ('secure', 'JJ'),
#   ('form', 'NN'),
#   ('screen', 'NN'),
#   ('unlocking', 'VBG')],
#  127: [('improved', 'VBN'),
#   ('durability', 'NN'),
#   ('mechanically', 'RB'),
#   ('retracting', 'VBG'),
#   ('front', 'JJ'),
#   ('facing', 'VBG'),
#   ('camera', 'NN'),
#   ('units', 'NNS'),
#   ('admittedly', 'RB'),
#   ('problematic', 'JJ'),
#   ('emergence', 'NN'),
#   ('screen', 'NN'),
#   ('cameras', 'NNS'),
#   ('seems', 'VBZ'),
#   ('like', 'IN'),
#   ('hole', 'NN'),
#   ('punch', 'NN'),
#   ('bit', 'NN'),
#   ('gap', 'JJ'),
#   ('filler', 'NN'),
#   ('people', 'NNS'),
#   ('desperate', 'VBP'),
#   ('screen', 'JJ'),
#   ('real', 'JJ'),
#   ('estate', 'NN')],
#  128: [('cameras', 'NNS'),
#   ('great', 'JJ'),
#   ('live', 'JJ'),
#   ('focus', 'NN'),
#   ('mode', 'NN'),
#   ('better', 'RBR'),
#   ('cases', 'NNS'),
#   ('even', 'RB'),
#   ('iphone', 'VBP'),
#   ('portrait', 'JJ'),
#   ('mode', 'NN'),
#   ('response', 'NN'),
#   ('time', 'NN'),
#   ('processing', 'VBG'),
#   ('power', 'NN'),
#   ('top', 'JJ'),
#   ('notch', 'NN'),
#   ('screen', 'NN'),
#   ('unbelievable', 'JJ')],
#  129: [('excellent', 'JJ'), ('camera', 'NN')],
#  130: [('love', 'VB'),
#   ('phone', 'NN'),
#   ('able', 'JJ'),
#   ('use', 'NN'),
#   ('either', 'CC'),
#   ('pin', 'NN'),
#   ('number', 'NN'),
#   ('fingerprint', 'NN'),
#   ('open', 'JJ')],
#  131: [('everything', 'NN'),
#   ('loads', 'NNS'),
#   ('fast', 'JJ'),
#   ('nice', 'JJ'),
#   ('voice', 'NN'),
#   ('recognition', 'NN'),
#   ('hands', 'NNS'),
#   ('free', 'JJ')],
#  132: [('battery', 'NN'),
#   ('life', 'NN'),
#   ('awesome', 'JJ'),
#   ('charging', 'VBG'),
#   ('battery', 'NN'),
#   ('faster', 'RBR'),
#   ('cellphone', 'NN'),
#   ('ever', 'RB'),
#   ('owned', 'VBD')],
#  133: [('serious', 'JJ'),
#   ('complaint', 'NN'),
#   ('fingerprint', 'NN'),
#   ('reader', 'NN'),
#   ('difficult', 'JJ'),
#   ('get', 'NN'),
#   ('hang', 'NN')],
#  134: [('issue', 'NN'),
#   ('run', 'VB'),
#   ('far', 'RB'),
#   ('screen', 'JJ'),
#   ('protectors', 'NNS'),
#   ('fingerprint', 'VBP'),
#   ('sensor', 'NN')],
#  135: [('battery', 'NN'),
#   ('life', 'NN'),
#   ('lasts', 'NNS'),
#   ('day', 'NN'),
#   ('long', 'RB'),
#   ('sometimes', 'RB'),
#   ('two', 'CD'),
#   ('days', 'NNS'),
#   ('moderate', 'JJ'),
#   ('usage', 'JJ'),
#   ('games', 'NNS'),
#   ('videos', 'VBP'),
#   ('charge', 'NN')],
#  136: [('far', 'RB'),
#   ('pleased', 'JJ'),
#   ('finger', 'NN'),
#   ('scanner', 'NN'),
#   ('works', 'VBZ'),
#   ('well', 'RB'),
#   ('seems', 'VBZ'),
#   ('trust', 'NN'),
#   ('worthy', 'NN'),
#   ('tried', 'VBD'),
#   ('face', 'NN'),
#   ('recognition', 'NN'),
#   ('yet', 'RB'),
#   ('sure', 'JJ'),
#   ('works', 'VBZ'),
#   ('well', 'RB')],
#  137: [('minimal', 'JJ'),
#   ('activity', 'NN'),
#   ('phone', 'NN'),
#   ('power', 'NN'),
#   ('saving', 'VBG'),
#   ('turned', 'VBD'),
#   ('battery', 'NN'),
#   ('lasts', 'NNS'),
#   ('entire', 'JJ'),
#   ('hrs', 'NN')],
#  138: [('received', 'VBN'),
#   ('package', 'NN'),
#   ('battery', 'NN'),
#   ('keeping', 'VBG'),
#   ('charge', 'NN'),
#   ('called', 'VBN'),
#   ('explained', 'VBD'),
#   ('issue', 'NN'),
#   ('agent', 'NN'),
#   ('suffering', 'VBG'),
#   ('battery', 'NN'),
#   ('drainage', 'NN'),
#   ('problems', 'NNS'),
#   ('days', 'NNS'),
#   ('get', 'VBP'),
#   ('replacement', 'NN'),
#   ('used', 'VBN'),
#   ('phone', 'NN')],
#  139: [('dont', 'NN'),
#   ('use', 'NN'),
#   ('face', 'NN'),
#   ('recognition', 'NN'),
#   ('dont', 'NN'),
#   ('know', 'VBP'),
#   ('good', 'JJ')],
#  140: [('phone', 'NN'),
#   ('crazy', 'NN'),
#   ('fast', 'RB'),
#   ('screen', 'JJ'),
#   ('sharp', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('great', 'JJ'),
#   ('fingerprint', 'NN'),
#   ('scanner', 'NN'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('camera', 'NN'),
#   ('also', 'RB'),
#   ('good', 'JJ')],
#  141: [('battery', 'NN'), ('life', 'NN'), ('good', 'JJ')],
#  142: [('great', 'JJ'),
#   ('screen', 'JJ'),
#   ('great', 'JJ'),
#   ('performance', 'NN'),
#   ('great', 'JJ'),
#   ('camera', 'NN')],
#  143: [('loved', 'VBN'),
#   ('crispiness', 'JJ'),
#   ('display', 'NN'),
#   ('keyboard', 'NN')],
#  144: [('dont', 'NN'),
#   ('know', 'VBP'),
#   ('camera', 'NN'),
#   ('display', 'NN'),
#   ('amazing', 'VBG')],
#  145: [('phone', 'NN'),
#   ('keeps', 'NNS'),
#   ('surprising', 'JJ'),
#   ('great', 'JJ'),
#   ('smart', 'JJ'),
#   ('phone', 'NN'),
#   ('great', 'JJ'),
#   ('camera', 'NN'),
#   ('great', 'JJ'),
#   ('reception', 'NN'),
#   ('great', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN')],
#  146: [('fingerprint', 'NN'),
#   ('reader', 'NN'),
#   ('horribly', 'RB'),
#   ('sensitive', 'JJ'),
#   ('really', 'RB'),
#   ('difficult', 'JJ'),
#   ('want', 'VBP'),
#   ('screen', 'JJ'),
#   ('protection', 'NN'),
#   ('honestly', 'RB'),
#   ('think', 'VBP'),
#   ('changed', 'VBN'),
#   ('people', 'NNS'),
#   ('would', 'MD'),
#   ('break', 'VB'),
#   ('phones', 'NNS')],
#  147: [('easy', 'JJ'),
#   ('set', 'VBN'),
#   ('issues', 'NNS'),
#   ('finger', 'RBR'),
#   ('print', 'NN'),
#   ('scanner', 'NN'),
#   ('complained', 'VBD')],
#  148: [('picture', 'NN'),
#   ('quality', 'NN'),
#   ('versatility', 'NN'),
#   ('cameras', 'NNS'),
#   ('outstanding', 'JJ')],
#  149: [('coming', 'VBG'),
#   ('earlier', 'RBR'),
#   ('camera', 'NN'),
#   ('blow', 'VB'),
#   ('away', 'RB'),
#   ('especially', 'RB'),
#   ('good', 'JJ'),
#   ('lighting', 'NN')],
#  150: [('screen', 'JJ'),
#   ('fingerprint', 'NN'),
#   ('scan', 'JJ'),
#   ('nice', 'JJ'),
#   ('become', 'NN'),
#   ('used', 'VBN'),
#   ('old', 'JJ'),
#   ('one', 'CD'),
#   ('fine', 'NN'),
#   ('although', 'IN'),
#   ('suspect', 'JJ'),
#   ('perpetual', 'JJ'),
#   ('fingerprints', 'NNS'),
#   ('camera', 'NN'),
#   ('lens', 'NNS')],
#  151: [('yet', 'RB'),
#   ('exercised', 'VBN'),
#   ('camera', 'NN'),
#   ('enough', 'JJ'),
#   ('declare', 'NN'),
#   ('value', 'NN'),
#   ('versus', 'NN'),
#   ('always', 'RB'),
#   ('found', 'VBD'),
#   ('camera', 'NN'),
#   ('excellent', 'NN')],
#  152: [('love', 'VB'), ('slim', 'NN'), ('design', 'NN')],
#  153: [('snapgradon', 'NN'),
#   ('buit', 'NN'),
#   ('ram', 'VBZ'),
#   ('quite', 'RB'),
#   ('good', 'JJ'),
#   ('speed', 'NN'),
#   ('huge', 'JJ'),
#   ('storage', 'NN')],
#  154: [('accurate', 'JJ'),
#   ('fast', 'RB'),
#   ('finger', 'JJ'),
#   ('print', 'NN'),
#   ('scanner', 'NN'),
#   ('face', 'NN'),
#   ('scanner', 'NN')],
#  155: [('yes', 'RB'),
#   ('phone', 'NN'),
#   ('finger', 'NN'),
#   ('print', 'NN'),
#   ('scanner', 'NN'),
#   ('function', 'NN'),
#   ('able', 'JJ'),
#   ('get', 'NN'),
#   ('strong', 'JJ'),
#   ('finger', 'NN'),
#   ('print', 'NN'),
#   ('compatible', 'JJ'),
#   ('screen', 'NN'),
#   ('protector', 'NN')],
#  156: [('loved', 'VBN'), ('color', 'NN'), ('storage', 'NN'), ('space', 'NN')],
#  157: [('greatest', 'JJS'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('seen', 'VBN')],
#  158: [('love', 'VB'),
#   ('phone', 'NN'),
#   ('great', 'JJ'),
#   ('performance', 'NN'),
#   ('responsive', 'NN'),
#   ('processer', 'NN')],
#  159: [('takes', 'VBZ'),
#   ('excellent', 'JJ'),
#   ('photos', 'NNS'),
#   ('videos', 'VBP'),
#   ('like', 'IN'),
#   ('pro', 'FW'),
#   ('camera', 'NN')],
#  160: [('works', 'NNS'),
#   ('fast', 'RB'),
#   ('efficient', 'JJ'),
#   ('low', 'JJ'),
#   ('bloat', 'NN'),
#   ('wear', 'NN'),
#   ('amazing', 'JJ'),
#   ('camera', 'NN')],
#  161: [('good', 'JJ'),
#   ('excellent', 'NN'),
#   ('camera', 'NN'),
#   ('good', 'JJ'),
#   ('performance', 'NN'),
#   ('fingerprint', 'NN'),
#   ('sensor', 'NN'),
#   ('bit', 'NN'),
#   ('slower', 'JJR'),
#   ('old', 'JJ'),
#   ('rear', 'NN'),
#   ('mounted', 'VBD'),
#   ('still', 'RB'),
#   ('works', 'VBZ'),
#   ('fine', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('good', 'JJ'),
#   ('design', 'NN'),
#   ('feels', 'NNS'),
#   ('high', 'JJ'),
#   ('quality', 'NN'),
#   ('strong', 'JJ'),
#   ('course', 'NN'),
#   ('phone', 'NN'),
#   ('survive', 'JJ'),
#   ('many', 'JJ'),
#   ('falls', 'NNS'),
#   ('bad', 'JJ'),
#   ('punch', 'JJ'),
#   ('hole', 'NN'),
#   ('selfie', 'NN'),
#   ('cameras', 'NNS'),
#   ('horrible', 'JJ'),
#   ('true', 'JJ')],
#  162: [('camera', 'NN'),
#   ('absolutely', 'RB'),
#   ('stunning', 'VBG'),
#   ('app', 'NN'),
#   ('packed', 'VBD'),
#   ('full', 'JJ'),
#   ('recording', 'NN'),
#   ('features', 'NNS')],
#  163: [('screen', 'NN'),
#   ('big', 'JJ'),
#   ('beautiful', 'NN'),
#   ('plus', 'CC'),
#   ('display', 'NN'),
#   ('technology', 'NN'),
#   ('saves', 'VBZ'),
#   ('battery', 'RB'),
#   ('lighting', 'JJ'),
#   ('color', 'NN'),
#   ('black', 'JJ')],
#  164: [('absolutely', 'RB'),
#   ('loves', 'VBZ'),
#   ('phone', 'NN'),
#   ('takes', 'VBZ'),
#   ('lot', 'NN'),
#   ('pictures', 'NNS'),
#   ('camera', 'VBP'),
#   ('upgrade', 'JJ'),
#   ('best', 'JJS'),
#   ('part', 'NN'),
#   ('upgrade', 'NN')],
#  165: [('loved', 'VBN'),
#   ('phone', 'NN'),
#   ('also', 'RB'),
#   ('tried', 'VBD'),
#   ('water', 'NN'),
#   ('resistance', 'NN'),
#   ('inside', 'IN'),
#   ('pool', 'NN'),
#   ('deep', 'JJ'),
#   ('worked', 'VBD'),
#   ('perfect', 'JJ'),
#   ('problems', 'NNS'),
#   ('putting', 'VBG'),
#   ('cell', 'NN'),
#   ('charge', 'NN'),
#   ('neither', 'CC'),
#   ('issues', 'NNS'),
#   ('speaker', 'NN'),
#   ('speakers', 'NNS'),
#   ('love', 'VBP'),
#   ('like', 'IN'),
#   ('stereo', 'NN'),
#   ('sound', 'NN'),
#   ('mono', 'NN'),
#   ('used', 'VBN'),
#   ('sound', 'JJ'),
#   ('older', 'JJR'),
#   ('phone', 'NN'),
#   ('camera', 'NN'),
#   ('amazing', 'VBG'),
#   ('videos', 'NN'),
#   ('pictures', 'NNS'),
#   ('would', 'MD'),
#   ('love', 'VB'),
#   ('work', 'NN'),
#   ('faster', 'RBR'),
#   ('flash', 'NN')],
#  166: [('fingerprint', 'NN'),
#   ('reader', 'NN'),
#   ('utterly', 'RB'),
#   ('worthless', 'NN')],
#  167: [('unfortunately', 'RB'),
#   ('one', 'CD'),
#   ('issue', 'NN'),
#   ('ruined', 'VBD'),
#   ('phone', 'NN'),
#   ('decided', 'VBD'),
#   ('return', 'NN'),
#   ('could', 'MD'),
#   ('pickup', 'VB'),
#   ('phone', 'NN'),
#   ('traditional', 'JJ'),
#   ('fingerprint', 'NN'),
#   ('reader', 'NN')],
#  168: [('phone', 'NN'),
#   ('performance', 'NN'),
#   ('specs', 'NN'),
#   ('amazing', 'VBG')],
#  169: [('believe', 'VB'),
#   ('horrible', 'JJ'),
#   ('fingerprint', 'NN'),
#   ('scanner', 'NN'),
#   ('thing', 'NN')],
#  170: [('complain', 'NN'),
#   ('phone', 'NN'),
#   ('fingerprint', 'NN'),
#   ('reader', 'NN')],
#  171: [('good', 'JJ'),
#   ('phone', 'NN'),
#   ('used', 'VBN'),
#   ('month', 'NN'),
#   ('flat', 'JJ'),
#   ('design', 'NN'),
#   ('chose', 'VBD'),
#   ('reason', 'NN'),
#   ('one', 'CD'),
#   ('comes', 'VBZ'),
#   ('snapdragon', 'RB'),
#   ('cpu', 'JJ'),
#   ('performs', 'NNS'),
#   ('perfectly', 'RB'),
#   ('without', 'IN'),
#   ('stuttering', 'VBG'),
#   ('fgo', 'NN')],
#  172: [('camera', 'NN'), ('amazing', 'NN')],
#  173: [('fingerprint', 'NN'),
#   ('sensor', 'NN'),
#   ('right', 'JJ'),
#   ('side', 'NN'),
#   ('uses', 'VBZ'),
#   ('thumb', 'NN')],
#  174: [('everything', 'NN'),
#   ('great', 'JJ'),
#   ('except', 'IN'),
#   ('fingerprint', 'JJ'),
#   ('scan', 'JJ'),
#   ('little', 'JJ'),
#   ('bit', 'NN'),
#   ('slow', 'JJ')],
#  175: [('camera', 'NN'), ('excellent', 'NN')],
#  176: [('one', 'CD'),
#   ('great', 'JJ'),
#   ('feature', 'NN'),
#   ('processor', 'NN'),
#   ('super', 'IN'),
#   ('fast', 'NN'),
#   ('downloading', 'VBG'),
#   ('surfing', 'VBG'),
#   ('web', 'NN'),
#   ('stable', 'JJ')],
#  177: [('finger', 'NN'),
#   ('print', 'NN'),
#   ('recognision', 'NN'),
#   ('easy', 'JJ'),
#   ('smooth', 'JJ'),
#   ('unlock', 'JJ'),
#   ('devise', 'NN'),
#   ('finger', 'NN'),
#   ('print', 'NN'),
#   ('faster', 'RBR'),
#   ('accurate', 'NN')],
#  178: [('phone', 'NN'),
#   ('supports', 'NNS'),
#   ('mirrorlink', 'VBP'),
#   ('use', 'NN'),
#   ('car', 'NN'),
#   ('built', 'VBN'),
#   ('display', 'NN'),
#   ('navigate', 'NN'),
#   ('using', 'VBG'),
#   ('paid', 'VBN'),
#   ('app', 'NN'),
#   ('sygic', 'NN'),
#   ('car', 'NN'),
#   ('connected', 'VBN'),
#   ('navigation', 'NN'),
#   ('microsoft', 'JJ'),
#   ('member', 'NN'),
#   ('consortium', 'NN'),
#   ('behind', 'IN'),
#   ('mirrorlink', 'NN'),
#   ('never', 'RB'),
#   ('finished', 'VBD'),
#   ('implementing', 'VBG'),
#   ('support', 'NN'),
#   ('windows', 'NNS'),
#   ('phone', 'NN'),
#   ('mobile', 'NN')],
#  179: [('pros', 'NNS'),
#   ('beautiful', 'JJ'),
#   ('design', 'NN'),
#   ('colors', 'NNS')],
#  180: [('cons', 'NNS'),
#   ('fragile', 'VBP'),
#   ('drop', 'NN'),
#   ('device', 'NN'),
#   ('hard', 'JJ'),
#   ('surface', 'NN')],
#  181: [('poor', 'JJ'),
#   ('selfie', 'NN'),
#   ('camera', 'NN'),
#   ('positioning', 'VBG'),
#   ('setup', 'NN'),
#   ('times', 'NNS'),
#   ('interferes', 'VBZ'),
#   ('apps', 'NNS')],
#  182: [('phone', 'NN'),
#   ('amazing', 'VBG'),
#   ('awesome', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('good', 'JJ'),
#   ('sounding', 'VBG'),
#   ('speakers', 'NNS'),
#   ('especially', 'RB'),
#   ('dolby', 'VBP'),
#   ('atoms', 'NNS'),
#   ('turned', 'VBD')],
#  183: [('battery', 'NN'), ('life', 'NN'), ('great', 'JJ')],
#  184: [('cameras', 'NNS'), ('awesome', 'VBP')],
#  185: [('anyway', 'RB'),
#   ('user', 'RBR'),
#   ('replaceable', 'JJ'),
#   ('battery', 'NN'),
#   ('surely', 'RB'),
#   ('hurt', 'VBN'),
#   ('couple', 'NN'),
#   ('years', 'NNS'),
#   ('new', 'JJ'),
#   ('phone', 'NN'),
#   ('great', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN')],
#  186: [('like', 'IN'),
#   ('screen', 'JJ'),
#   ('fingerprint', 'NN'),
#   ('reader', 'NN'),
#   ('much', 'JJ'),
#   ('one', 'CD'),
#   ('home', 'NN'),
#   ('key', 'NN'),
#   ('still', 'RB'),
#   ('works', 'VBZ'),
#   ('well', 'RB')],
#  187: [('camera', 'NN'), ('good', 'NN')],
#  188: [('rapid', 'JJ'),
#   ('charging', 'VBG'),
#   ('works', 'VBZ'),
#   ('great', 'JJ')],
#  189: [('screen', 'NN'),
#   ('amazing', 'VBG'),
#   ('colorful', 'JJ'),
#   ('cameras', 'NNS'),
#   ('takes', 'VBZ'),
#   ('really', 'RB'),
#   ('goof', 'JJ'),
#   ('pictures', 'NNS'),
#   ('also', 'RB'),
#   ('selfies', 'VBZ'),
#   ('big', 'JJ'),
#   ('selfie', 'NNS'),
#   ('person', 'NN'),
#   ('even', 'RB'),
#   ('front', 'JJ'),
#   ('camera', 'NN'),
#   ('impressed', 'VBD')],
#  190: [('disappointed', 'JJ'),
#   ('annoyed', 'VBD'),
#   ('fact', 'NN'),
#   ('indicator', 'NN'),
#   ('light', 'JJ'),
#   ('let', 'NN'),
#   ('know', 'VB'),
#   ('message', 'NN'),
#   ('missed', 'VBN'),
#   ('call', 'VB'),
#   ('even', 'RB'),
#   ('phone', 'NN'),
#   ('charging', 'VBG'),
#   ('finished', 'VBN'),
#   ('charging', 'VBG'),
#   ('focus', 'RB'),
#   ('good', 'JJ'),
#   ('aspects', 'NNS'),
#   ('device', 'NN')],
#  191: [('samsung', 'NN'),
#   ('always', 'RB'),
#   ('beat', 'VBD'),
#   ('sony', 'JJ'),
#   ('phones', 'NNS'),
#   ('terms', 'NNS'),
#   ('camera', 'VBP'),
#   ('quality', 'NN'),
#   ('bit', 'NN'),
#   ('disappointed', 'JJ'),
#   ('quality', 'NN'),
#   ('xperia', 'NNS')],
#  192: [('expecting', 'VBG'),
#   ('samsung', 'NN'),
#   ('far', 'RB'),
#   ('ahead', 'RB'),
#   ('sony', 'JJ'),
#   ('camera', 'NN'),
#   ('department', 'NN'),
#   ('one', 'CD'),
#   ('shocks', 'NNS')],
#  193: [('said', 'VBD'),
#   ('know', 'VBP'),
#   ('far', 'RB'),
#   ('phone', 'NN'),
#   ('indeed', 'RB'),
#   ('unlocked', 'JJ'),
#   ('version', 'NN'),
#   ('definitely', 'RB'),
#   ('snapdragon', 'VBD'),
#   ('processor', 'NN')],
#  194: [('phone', 'NN'),
#   ('fast', 'JJ'),
#   ('graphics', 'NNS'),
#   ('performance', 'NN'),
#   ('excellent', 'NN'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('significant', 'JJ'),
#   ('improvement', 'NN')],
#  195: [('checked', 'VBN'),
#   ('first', 'JJ'),
#   ('earbuds', 'NNS'),
#   ('fingerprint', 'VBP'),
#   ('sensitive', 'JJ'),
#   ('fast', 'NN')],
#  196: [('really', 'RB'), ('pleased', 'JJ'), ('battery', 'NN'), ('life', 'NN')],
#  197: [('performance', 'NN'), ('good', 'NN')],
#  198: [('got', 'VBD'),
#   ('phone', 'NN'),
#   ('yesterday', 'NN'),
#   ('far', 'RB'),
#   ('amazing', 'VBG'),
#   ('phone', 'NN'),
#   ('great', 'JJ'),
#   ('performance', 'NN'),
#   ('beautiful', 'NN'),
#   ('screen', 'NN'),
#   ('upgraded', 'VBD'),
#   ('galaxy', 'NN'),
#   ('far', 'RB'),
#   ('say', 'VBP'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('upgrade', 'NN'),
#   ('fingerprint', 'NN'),
#   ('sensor', 'NN'),
#   ('screen', 'NN'),
#   ('great', 'JJ'),
#   ('works', 'VBZ'),
#   ('well', 'RB')],
#  199: [('first', 'RB'),
#   ('thought', 'VBN'),
#   ('using', 'VBG'),
#   ('first', 'JJ'),
#   ('time', 'NN'),
#   ('wow', 'NN'),
#   ('beautiful', 'JJ'),
#   ('display', 'NN'),
#   ('experience', 'NN'),
#   ('necessarily', 'RB'),
#   ('last', 'JJ'),
#   ('rest', 'NN'),
#   ('galaxy', 'NN'),
#   ('offer', 'NN'),
#   ('said', 'VBD'),
#   ('done', 'VBN'),
#   ('ended', 'VBD'),
#   ('returning', 'VBG')],
#  200: [('bold', 'JJ'), ('beautiful', 'JJ'), ('display', 'NN')],
#  201: [('galaxy', 'RB'),
#   ('good', 'JJ'),
#   ('device', 'NN'),
#   ('overpriced', 'VBD'),
#   ('overdesigned', 'VBN'),
#   ('imho', 'NN')],
#  202: [('camera', 'NN'),
#   ('first', 'RB'),
#   ('rate', 'NN'),
#   ('storage', 'NN'),
#   ('likely', 'JJ'),
#   ('use', 'NN'),
#   ('long', 'JJ'),
#   ('time', 'NN')],
#  203: [('pull', 'NN'),
#   ('coworkers', 'NNS'),
#   ('would', 'MD'),
#   ('pull', 'VB'),
#   ('apple', 'NN'),
#   ('product', 'NN'),
#   ('would', 'MD'),
#   ('look', 'VB'),
#   ('like', 'IN'),
#   ('quarantined', 'JJ'),
#   ('thick', 'NN'),
#   ('nasty', 'JJ'),
#   ('layers', 'NNS'),
#   ('fingerprints', 'NNS')],
#  204: [('quickly', 'RB'),
#   ('learned', 'VBD'),
#   ('sorts', 'NNS'),
#   ('usb', 'JJ'),
#   ('cables', 'NNS'),
#   ('world', 'NN'),
#   ('like', 'IN'),
#   ('mine', 'JJ'),
#   ('charging', 'VBG'),
#   ('like', 'IN'),
#   ('stupid', 'JJ'),
#   ('samsung', 'NN'),
#   ('charging', 'VBG'),
#   ('cable', 'NN'),
#   ('got', 'VBD'),
#   ('charging', 'VBG'),
#   ('came', 'VBD'),
#   ('across', 'IN'),
#   ('something', 'NN'),
#   ('getting', 'VBG'),
#   ('started', 'VBN'),
#   ('said', 'VBD'),
#   ('phone', 'NN'),
#   ('comes', 'VBZ'),
#   ('factory', 'NN'),
#   ('installed', 'JJ'),
#   ('screen', 'NN'),
#   ('protector', 'NN')],
#  205: [('needs', 'NNS'), ('charging', 'VBG'), ('night', 'NN')],
#  206: [('charging', 'VBG'), ('block', 'NN'), ('came', 'VBD'), ('bad', 'JJ')],
#  207: [('like', 'IN'),
#   ('gigs', 'NNS'),
#   ('ram', 'VBP'),
#   ('far', 'RB'),
#   ('better', 'JJR'),
#   ('phone', 'NN'),
#   ('replaced', 'VBD'),
#   ('note', 'NN'),
#   ('edge', 'NN'),
#   ('gigs', 'VBD'),
#   ('new', 'JJ'),
#   ('processor', 'NN'),
#   ('smokes', 'NNS'),
#   ('compared', 'VBN'),
#   ('old', 'JJ'),
#   ('phone', 'NN')],
#  208: [('camera', 'NN'),
#   ('new', 'JJ'),
#   ('cool', 'NN'),
#   ('features', 'NNS'),
#   ('image', 'NN'),
#   ('quality', 'NN'),
#   ('bit', 'NN'),
#   ('better', 'RBR')],
#  209: [('really', 'RB'),
#   ('enjoy', 'VB'),
#   ('ultra', 'JJ'),
#   ('wide', 'JJ'),
#   ('lens', 'NNS'),
#   ('camera', 'NN'),
#   ('something', 'NN'),
#   ('long', 'JJ'),
#   ('time', 'NN'),
#   ('glad', 'JJ'),
#   ('samsung', 'NN'),
#   ('picked', 'VBD')]}

# %%
#For S10

prevWordS10=''
prevTagS10=''
currWordS10=''
aspectListS10=[]
outputDictS10={}
#Extracting Aspects
for key,value in S10data_dict.items():
    for word,tag in value:
        if(tag=='NN' or tag=='NNP'):
            if(prevTagS10=='NN' or prevTagS10=='NNP'):
                currWordS10= prevWordS10 + ' ' + word
            else:
                aspectListS10.append(prevWordS10.upper())
                currWordS10= word
        prevWordS10=currWordS10
        prevTagS10=tag
#Eliminating aspect which has 1 or less count
for aspect in aspectListS10:
        if(aspectListS10.count(aspect)>1):
                if(outputDictS10.keys()!=aspect):
                        outputDictS10[aspect]=aspectListS10.count(aspect)
outputAspectS10=sorted(outputDictS10.items(), key=lambda x: x[1],reverse = True)

# %%
outputAspectS10
# Out:
# [('PHONE', 27),
#  ('CAMERA', 23),
#  ('BATTERY LIFE', 19),
#  ('SCREEN', 9),
#  ('BATTERY', 6),
#  ('USE', 6),
#  ('LIFE', 6),
#  ('TIME', 5),
#  ('FINGERPRINT SCANNER', 4),
#  ('FINGERPRINT', 4),
#  ('FAST', 3),
#  ('ISSUE', 3),
#  ('FACE RECOGNITION', 3),
#  ('FINGERPRINT SENSOR', 3),
#  ('CASE', 3),
#  ('PROCESSOR', 3),
#  ('STORAGE', 3),
#  ('SUPPORT', 3),
#  ('SAMSUNG', 3),
#  ('FINGERPRINT READER', 3),
#  ('DESIGN', 3),
#  ('SIDE', 2),
#  ('GET', 2),
#  ('DAY', 2),
#  ('POWER', 2),
#  ('COOL', 2),
#  ('GALAXY', 2),
#  ('PURCHASE', 2),
#  ('THING', 2),
#  ('EVERYTHING', 2),
#  ('FINGER PRINT READER', 2),
#  ('DISPLAY', 2),
#  ('USE CAR', 2),
#  ('DISPLAY NAVIGATE', 2),
#  ('APP SYGIC CAR', 2),
#  ('NAVIGATION', 2),
#  ('MEMBER CONSORTIUM', 2),
#  ('MIRRORLINK', 2),
#  ('PHONE MOBILE', 2),
#  ('SECURE', 2),
#  ('WORTHLESS', 2),
#  ('IMPROVEMENT', 2),
#  ('CHARGE', 2),
#  ('CAMERA EXCELLENT', 2),
#  ('SCREEN PROTECTOR', 2),
#  ('QUALITY', 2),
#  ('PHONE CAMERA', 2)]

# %%
#For S10
new=[]
for x in outputAspectS10:
    if x[0] == 'PHONE' or x[0] == 'CAMERA' or x[0] == 'BATTERY LIFE' or x[0] == 'SCREEN' or x[0] == 'BATTERY' or x[0] == 'FINGERPRINT SCANNER' or x[0] == 'FINGERPRINT' or x[0] == 'FINGERPRINT READER' or x[0] == 'FACE RECOGNITION' or x[0] == 'FINGERPRINT SENSOR' or x[0] == 'PROCESSOR' or x[0] == 'STORAGE' or x[0] == 'DESIGN' or x[0] == 'FINGER PRINT READER' or x[0] == 'DISPLAY' or x[0] == 'SECURE' or x[0] == 'PHONE CAMERA' or x[0] == 'SCREEN PROTECTOR':
        new.append(x)

# %%
new
# Out:
# [('PHONE', 27),
#  ('CAMERA', 23),
#  ('BATTERY LIFE', 19),
#  ('SCREEN', 9),
#  ('BATTERY', 6),
#  ('FINGERPRINT SCANNER', 4),
#  ('FINGERPRINT', 4),
#  ('FACE RECOGNITION', 3),
#  ('FINGERPRINT SENSOR', 3),
#  ('PROCESSOR', 3),
#  ('STORAGE', 3),
#  ('FINGERPRINT READER', 3),
#  ('DESIGN', 3),
#  ('FINGER PRINT READER', 2),
#  ('DISPLAY', 2),
#  ('SECURE', 2),
#  ('SCREEN PROTECTOR', 2),
#  ('PHONE CAMERA', 2)]

# %%
#For S10

def orientation(inputWord):
    wordSynset=wordnet.synsets(inputWord)
    if(len(wordSynset) != 0):
        word=wordSynset[0].name()
        orientation=sentiwordnet.senti_synset(word)
        if(orientation.pos_score()>orientation.neg_score()):
            return True
        elif(orientation.pos_score()<orientation.neg_score()):
            return False

outputAspectOpinionTuplesS10={}
orientationCacheS10={}
negativeWordSet = {"don't","never", "nothing", "nowhere", "noone", "none", "not",
              "hasn't","hadn't","can't","couldn't","shouldn't","won't",
              "wouldn't","don't","doesn't","didn't","isn't","aren't","ain't"}
for aspect,no in new:
    aspectTokens= word_tokenize(aspect)
    #print(aspectTokens)
    count=0
    for key,value in S10data_dict.items():
        condition=True
        isNegativeSen=False
        for subWord in aspectTokens:
            #print(subWord)
            if(subWord in str(value).upper()):
                condition = condition and True
            else:
                condition = condition and False
        if(condition):
            for negWord in negativeWordSet:
                if(not isNegativeSen):#once senetence is negative no need to check this condition again and again
                    if negWord.upper() in str(value).upper():
                        isNegativeSen=isNegativeSen or True
            outputAspectOpinionTuplesS10.setdefault(aspect,[0,0,0])
            for word,tag in value:
                 if(tag=='JJ' or tag=='JJR' or tag=='JJS'or tag== 'RB' or tag== 'RBR'or tag== 'RBS'):
                    #print(tag)   
                    count+=1
                    if(word not in orientationCacheS10):
                        orien=orientation(word)
                        orientationCacheS10[word]=orien
                    else:
                        orien=orientationCacheS10[word]
                    if(isNegativeSen and orien is not None):
                        orien= not orien
                    if(orien==True):
                        outputAspectOpinionTuplesS10[aspect][0]+=1
                    elif(orien==False):
                        outputAspectOpinionTuplesS10[aspect][1]+=1
                    elif(orien is None):
                        outputAspectOpinionTuplesS10[aspect][2]+=1

    if(count>0):
        #print(count)
        outputAspectOpinionTuplesS10[aspect][0]=round((outputAspectOpinionTuplesS10[aspect][0]/count)*100,2)
        outputAspectOpinionTuplesS10[aspect][1]=round((outputAspectOpinionTuplesS10[aspect][1]/count)*100,2)
        outputAspectOpinionTuplesS10[aspect][2]=round((outputAspectOpinionTuplesS10[aspect][2]/count)*100,2)

S10DF = pd.DataFrame(outputAspectOpinionTuplesS10).T
S10DF.columns = ['Percentage Positive', 'Percentage Negative', 'Percentage Neutral']
S10DF.iloc[:,0:2]
# Out:
#                      Percentage Positive  Percentage Negative
# PHONE                              31.88                10.48
# CAMERA                             33.76                11.39
# BATTERY LIFE                       37.58                 5.37
# SCREEN                             27.68                11.86
# BATTERY                            37.43                 6.70
# FINGERPRINT SCANNER                41.18                20.59
# FINGERPRINT                        26.42                17.61
# FACE RECOGNITION                   23.53                11.76
# FINGERPRINT SENSOR                 16.95                15.25
# PROCESSOR                          16.67                12.50
# STORAGE                            22.22                16.67
# FINGERPRINT READER                 34.21                15.79
# DESIGN                             38.46                15.38
# FINGER PRINT READER                31.82                15.91
# DISPLAY                            33.33                15.38
# SECURE                             28.57                14.29
# SCREEN PROTECTOR                   40.00                 5.00
# PHONE CAMERA                       31.82                11.82

# %%
XRdata_dict = XRrev_useful['tagged'].to_dict()

# %%
#For XR
prevWordXR=''
prevTagXR=''
currWordXR=''
aspectListXR=[]
outputDictXR={}
#Extracting Aspects
for key,value in XRdata_dict.items():
    for word,tag in value:
        if(tag=='NN' or tag=='NNP'):
            if(prevTagXR=='NN' or prevTagXR=='NNP'):
                currWordXR= prevWordXR + ' ' + word
            else:
                aspectListXR.append(prevWordXR.upper())
                currWordXR= word
        prevWordXR=currWordXR
        prevTagXR=tag
#Eliminating aspect which has 1 or less count
for aspect in aspectListXR:
        if(aspectListXR.count(aspect)>1):
                if(outputDictXR.keys()!=aspect):
                        outputDictXR[aspect]=aspectListXR.count(aspect)
outputAspectXR=sorted(outputDictXR.items(), key=lambda x: x[1],reverse = True)

# %%
outputAspectXR
# Out:
# [('PHONE', 39),
#  ('BATTERY LIFE', 39),
#  ('CAMERA', 34),
#  ('IPHONE', 27),
#  ('PERFORMANCE', 25),
#  ('BATTERY', 21),
#  ('DAY', 16),
#  ('BATTERY BACKUP', 13),
#  ('LIFE', 13),
#  ('DISPLAY', 12),
#  ('PRODUCT', 11),
#  ('QUALITY', 10),
#  ('CAMERA QUALITY', 9),
#  ('FACE RECOGNITION', 8),
#  ('APPLE', 7),
#  ('TIME', 6),
#  ('CHARGE', 5),
#  ('PROCESSOR', 5),
#  ('INTERFACE', 5),
#  ('FACE DETECTION', 5),
#  ('SIM', 4),
#  ('CHARGER', 4),
#  ('CAMERA BATTERY LIFE', 4),
#  ('PORTRAIT MODE', 4),
#  ('FACE', 4),
#  ('FACE UNLOCK', 3),
#  ('ISSUE', 3),
#  ('BIT', 3),
#  ('USE', 3),
#  ('PROBLEM', 3),
#  ('PRICE', 3),
#  ('THING', 3),
#  ('SCREEN', 3),
#  ('PORTRAIT', 3),
#  ('EXPERIENCE', 3),
#  ('IPHONE CAMERA', 3),
#  ('SIDE', 2),
#  ('ZOOM', 2),
#  ('USE CAMERA', 2),
#  ('FRONT CAMERA', 2),
#  ('ADAPTER', 2),
#  ('BATTERY PERFORMANCE', 2),
#  ('CAMERA PERFORMANCE', 2),
#  ('QUALITY CAMERA', 2),
#  ('JOB', 2),
#  ('FINGERPRINT READER', 2),
#  ('YOUTUBE', 2),
#  ('THINK', 2),
#  ('CHIP', 2),
#  ('SYSTEM', 2),
#  ('USAGE', 2),
#  ('SPEAKER', 2),
#  ('PHONE CAMERA', 2),
#  ('CON', 2),
#  ('CAMERA PICTURE QUALITY', 2),
#  ('ANDROID', 2),
#  ('COLOUR', 2),
#  ('FRONT CAMERA QUALITY', 2),
#  ('IDEA', 2),
#  ('BATTERY BACKUP CAMERA', 2),
#  ('FACE LOCK', 2),
#  ('PHONE APPLE', 2),
#  ('FEEL', 2),
#  ('NOTHING', 2),
#  ('MODE', 2)]

# %%
#For XR
newXR=[]
for x in outputAspectXR:
    if x[0] == 'PHONE' or x[0] == 'CAMERA' or x[0] == 'BATTERY LIFE' or x[0] == 'BATTERY BACKUP' or x[0] == 'BATTERY' or x[0] == 'DISPLAY' or x[0] == 'CAMERA QUALITY' or x[0] == 'PERFORMANCE' or x[0] == 'FACE RECOGNITION' or x[0] == 'PROCESSOR' or x[0] == 'INTERFACE' or x[0] == 'FACE DETECTION' or x[0] == 'FACE UNLOCK' or x[0] == 'SCREEN' or x[0] == 'DISPLAY' or x[0] == 'FRONT CAMERA' or x[0] == 'BATTERY PERFORMANCE' or x[0] == 'CHIP' or x[0] == 'SPEAKER' or x[0] == 'CAMERA PICTURE QUALITY' or x[0] == 'PRICE' or x[0] == 'ADAPTER' or x[0] == 'ANDROID'or x[0] == 'CHIP'or x[0] == 'COLOR':
        newXR.append(x)

# %%
newXR
# Out:
# [('PHONE', 39),
#  ('BATTERY LIFE', 39),
#  ('CAMERA', 34),
#  ('PERFORMANCE', 25),
#  ('BATTERY', 21),
#  ('BATTERY BACKUP', 13),
#  ('DISPLAY', 12),
#  ('CAMERA QUALITY', 9),
#  ('FACE RECOGNITION', 8),
#  ('PROCESSOR', 5),
#  ('INTERFACE', 5),
#  ('FACE DETECTION', 5),
#  ('FACE UNLOCK', 3),
#  ('PRICE', 3),
#  ('SCREEN', 3),
#  ('FRONT CAMERA', 2),
#  ('ADAPTER', 2),
#  ('BATTERY PERFORMANCE', 2),
#  ('CHIP', 2),
#  ('SPEAKER', 2),
#  ('CAMERA PICTURE QUALITY', 2),
#  ('ANDROID', 2)]

# %%
#For XR

outputAspectOpinionTuplesXR={}
orientationCacheXR={}
negativeWordSet = {"don't","never", "nothing", "nowhere", "noone", "none", "not",
              "hasn't","hadn't","can't","couldn't","shouldn't","won't",
              "wouldn't","don't","doesn't","didn't","isn't","aren't","ain't"}

for aspect,no in newXR:
    aspectTokens= word_tokenize(aspect)
    count=0
    for key,value in XRdata_dict.items():
        condition=True
        isNegativeSen=False
        for subWord in aspectTokens:
            if(subWord in str(value).upper()):
                condition = condition and True
            else:
                condition = condition and False
        if(condition):
            for negWord in negativeWordSet:
                if(not isNegativeSen):#once senetence is negative no need to check this condition again and again
                    if negWord.upper() in str(value).upper():
                        isNegativeSen=isNegativeSen or True
            outputAspectOpinionTuplesXR.setdefault(aspect,[0,0,0])
            for word,tag in value:
                 if(tag=='JJ' or tag=='JJR' or tag=='JJS'or tag== 'RB' or tag== 'RBR'or tag== 'RBS'):
                    count+=1
                    if(word not in orientationCacheXR):
                        orien=orientation(word)
                        orientationCacheXR[word]=orien
                    else:
                        orien=orientationCacheXR[word]
                    if(isNegativeSen and orien is not None):
                        orien= not orien
                    if(orien==True):
                        outputAspectOpinionTuplesXR[aspect][0]+=1
                    elif(orien==False):
                        outputAspectOpinionTuplesXR[aspect][1]+=1
                    elif(orien is None):
                        outputAspectOpinionTuplesXR[aspect][2]+=1
    if(count>0):
        outputAspectOpinionTuplesXR[aspect][0]=round((outputAspectOpinionTuplesXR[aspect][0]/count)*100,2)
        outputAspectOpinionTuplesXR[aspect][1]=round((outputAspectOpinionTuplesXR[aspect][1]/count)*100,2)
        outputAspectOpinionTuplesXR[aspect][2]=round((outputAspectOpinionTuplesXR[aspect][2]/count)*100,2)

XRDF = pd.DataFrame(outputAspectOpinionTuplesXR).T
XRDF.columns = ['Percentage Positive', 'Percentage Negative', 'Percentage Neutral']
XRDF.iloc[:,0:2]
# Out:
#                         Percentage Positive  Percentage Negative
# PHONE                                 31.33                11.66
# BATTERY LIFE                          37.00                 7.95
# CAMERA                                37.40                 9.54
# PERFORMANCE                           36.26                11.70
# BATTERY                               34.58                 8.47
# BATTERY BACKUP                        40.00                10.00
# DISPLAY                               33.08                10.77
# CAMERA QUALITY                        46.27                 6.72
# FACE RECOGNITION                      36.11                11.11
# PROCESSOR                             30.77                 2.56
# INTERFACE                             22.00                 4.00
# FACE DETECTION                        30.43                 8.70
# FACE UNLOCK                           31.67                 3.33
# PRICE                                 15.09                24.53
# SCREEN                                36.92                12.31
# FRONT CAMERA                          25.00                 8.33
# ADAPTER                               25.00                25.00
# BATTERY PERFORMANCE                   30.00                12.50
# CHIP                                  13.64                22.73
# SPEAKER                               29.63                 7.41
# CAMERA PICTURE QUALITY                58.33                 8.33
# ANDROID                               13.39                20.54
